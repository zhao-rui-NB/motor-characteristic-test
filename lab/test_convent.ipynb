# %%
import os

# convert.exe <work_dir> <phase> <run_process_cmd>

work_dir = rf'C:\Users\MyUser\Desktop\test_cvt\20250323_160953'
phase = '1'
run_process_cmd = '123479abq'

cmd = f"./convert.exe {work_dir} {phase} {run_process_cmd}"

print("Running command:", cmd)
# os.system(cmd)
# Out:
# Running command: ./convert.exe C:\Users\MyUser\Desktop\test_cvt\20250323_160953 1 123479abq

# %%
import subprocess

# 使用 subprocess.run 来执行命令
# result = subprocess.run(['./convert.exe', work_dir, phase, run_process_cmd], capture_output=True, text=True, encoding='utf-8')
result = subprocess.run(['./convert.exe', work_dir, phase, run_process_cmd], capture_output=True, text=True, errors='replace')


# result = subprocess.run(['./convert.exe', work_dir, phase, run_process_cmd],
#     capture_output=True, text=True, encoding='cp1252'
# )

print(result.stdout)
print(result.stderr)
print(result.returncode)
# Out:
# /The current date/time is: 1743421319
# 2025/3/31 19/41/59
# Current working directory: c:\Users\MyUser\Desktop\motor-characteristic-test
# The program name is ./convert.exe
# The command line has 3 argument:
# 1 : C:\Users\MyUser\Desktop\test_cvt\20250323_160953
# 2 : 1
# 3 : 123479abq
# input file open ok
#
# mot[j]= 0 key,value
# 0:key 1:value 2: 3:
#
# 1.Key = value
#
# mot[j]= 1 ���閮�,
# 0:���閮� 1: 2: 3:
#
#
# mot[j]= 2 閰阡����交��,20250318
# 0:閰阡����交�� 1:20250318 2: 3:
#
#
# mot[j]= 3 ��餉�衣楊���,110V1PH1HP
# 0:��餉�衣楊��� 1:110V1PH1HP 2: 3:
#
#
# mot[j]= 4 瑼ａ�����,��喲暑皞�
# 0:瑼ａ����� 1:��喲暑皞� 2: 3:
#
#
# mot[j]= 5 摨����,SF123
# 0:摨���� 1:SF123 2: 3:
#
#
# mot[j]= 6 ���撘�,T123
# 0:���撘� 1:T123 2: 3:
#
#
# mot[j]= 7 撌乩����株��,W1140312
# 0:撌乩����株�� 1:W1140312 2: 3:
#
#
# mot[j]= 8 鋆賡�����蝣�,M123
# 0:鋆賡�����蝣� 1:M123 2: 3:
#
#
# mot[j]= 9 撱����,SHOWFU
# 0:撱���� 1:SHOWFU 2: 3:
#
#
# mot[j]=10 摰�摮�閬����,123
# 0:摰�摮�閬���� 1:123 2: 3:
#
#
# mot[j]=11 頧�摮�閬����,456
# ...
